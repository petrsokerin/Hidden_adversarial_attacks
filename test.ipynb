# %%
# !git clone https://github.com/petrsokerin/Hidden_adversarial_attacks

# %%
# !nvidia-smi
# Out:
# Mon Dec 25 18:54:34 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.86.10              Driver Version: 535.86.10    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:1A:00.0 Off |                    0 |
# | N/A   43C    P0              78W / 300W |  12751MiB / 16384MiB |    100%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import pandas as pd

from matplotlib import pyplot  as plt

# %%
data = pd.read_csv('/cephfs/projects/danikin/aa/HAA/results/FordA/IFGSM/fgsm_attack_with_sig/aa_res_FordA_0.csv', index_col=0)

# %%
data['eps']
# Out:
# 0     0.001
# 1     0.001
# 2     0.001
# 3     0.001
# 4     0.001
#       ...
# 26    0.005
# 27    0.005
# 28    0.005
# 29    0.005
# 30    0.005
# Name: eps, Length: 155, dtype: float64

# %%
data.drop(columns=['eps', 'PR AUC', 'ROC AUC', 'n steps']).plot()

for eps in data['eps'].unique():
    plt.plot(data[data['eps']==eps][['ACC', 'HID']])

plt.show()
